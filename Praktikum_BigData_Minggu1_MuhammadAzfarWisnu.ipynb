# %% [markdown]
# Nama : Muhammad Azfar Wisnu
#
# Kelas : 2IA02
#
# NPM : 50420803

# %% [markdown]
# 1.Modifikasi kode operasi yang ada menggunakan GPU (Cupy)
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from scipy import stats
plt.style.use("ggplot")
import warnings
warnings.filterwarnings("ignore")
from scipy import stats

#read data from csv raw
csv_data = ("https://raw.githubusercontent.com/supasonicx/ATA-praktikum-01/main/data.csv")
data = pd.read_csv(csv_data)
data = data.drop(['Unnamed: 32','id'],axis = 1)
data.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# 2.Buatlah diagram kolerasi dari fitur compatcness_mean dengan concavity_mean

# %%
f, ax = plt.subplots(figsize = (18,18))
sns.heatmap(data.corr(), annot=True, linewidths=0.5, fmt=".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title("Colerration Map")
plt.savefig("graphColleration.png")
plt.show()

# %% [markdown]
# 3.Buatlah diagram korelasi dari fitur compactness_mean dengan concavity_mean

# %%
plt.figure(figsize = (15,10))
sns.jointplot(data.radius_mean,data.area_mean,kind="reg")
plt.show()

# %% [markdown]
# 4.Hitung nilai covariance dari fitur compactness_mean dengan concavity_mean. Jelaskan arti dari nilai tersebut.

# %%
cp.cov(data.compactness_mean,data.concavity_mean)
print("Covariance antara compactness mean dengan concavity mean", data.compactness_mean.cov(data.concavity_mean))
# Out:
# Covariance antara compactness mean dengan concavity mean 0.003718134921780181

# %% [markdown]
# 5.Hitung nilai pearson correlation dari fitur compactness_mean dengan concavity_mean. Jelaskan arti dari nilai tersebut.

# %%
p1 = data.loc[:,["compactness_mean", "concavity_mean"]].corr(method="pearson")
p2 = data.concavity_mean.cov(data.compactness_mean)/(data.concavity_mean.std()*data.compactness_mean.std())
print("Pearson correlation: ")
print(p1)
print("Pearson colleartion: ", p2)
# Out:
# Pearson correlation:
#                   compactness_mean  concavity_mean
# compactness_mean          1.000000        0.883121
# concavity_mean            0.883121        1.000000
# Pearson colleartion:  0.8831206701772506

# %% [markdown]
# 6.Lakukan uji hipotesis untuk kolom fitur compactness_mean dengan concavity_mean yang berbeda serta
# berikan penjelasan terhadap hasil dari uji hipotesis yang dilakukan.

# %%
statistics , p_value = stats.ttest_rel(data.compactness_mean, data.concavity_mean)
print("P_value: {:.20f}".format(p_value))

if(p_value_int >= 0 and p_value_int < 1):
  print("mendekati nol, hasil menolak hipotesis nol")
elif(p_value_int > 1):
  print("tidak mendekati 0, hasil menerima hipotesis nol")
# Out:
# P_value: 0.00000000000000000429
# mendekati nol, hasil menolak hipotesis nol
